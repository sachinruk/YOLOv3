# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from detect import *
from model.yolo_model import YOLO
import time

from keras.models import load_model

# %matplotlib inline
# Out:
# /Users/sachin/miniconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
yolo = YOLO(0.5, 0.6)
all_classes = get_classes('./data/coco_classes.txt')
start = time.time()
image = cv2.imread('./images/test/horses.jpg')
image = detect_image(image, yolo, all_classes)
end = time.time()
print('time: {0:.2f}s'.format(end - start))
# Out:
# WARNING:tensorflow:From /Users/sachin/miniconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1238: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# /Users/sachin/miniconda3/lib/python3.6/site-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# class: horse, score: 1.00
# box coordinate x,y,w,h: [421.64872414 226.08786011 192.07974504 109.14268494]
# class: horse, score: 1.00
# box coordinate x,y,w,h: [-16.09628411 214.3145752  369.92529094 178.89428711]
# class: horse, score: 0.85
# box coordinate x,y,w,h: [222.56996819 209.0032959  236.75569707 135.94633484]
# class: horse, score: 0.74
# box coordinate x,y,w,h: [-13.21999814 202.29724121 199.63720059 157.99095154]
#
# time: 6.20s

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
